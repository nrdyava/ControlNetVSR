# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
axes[2][0].imshow(np.asarray(Image.open("frames/cn-50/011/00000010.png")))
axes[2][1].imshow(np.asarray(Image.open("frames/cn-50/011/00000011.png")))
axes[2][2].imshow(np.asarray(Image.open("frames/cn-50/011/00000012.png")))
axes[2][3].imshow(np.asarray(Image.open("frames/cn-50/011/00000013.png")))

# %%
fig, axes = plt.subplots(1, 4, figsize=(16, 6))

axes[0].imshow(np.asarray(Image.open("frames/hr/011/00000010.png")))
axes[1].imshow(np.asarray(Image.open("frames/hr/011/00000011.png")))
axes[2].imshow(np.asarray(Image.open("frames/hr/011/00000012.png")))
axes[3].imshow(np.asarray(Image.open("frames/hr/011/00000013.png")))

for ax in axes:
    ax.axis('off')

plt.show()
