# %%
import requests
from PIL import Image
from io import BytesIO
from diffusers import StableDiffusionUpscalePipeline
import torch
import os

# %%
model_id = "stabilityai/stable-diffusion-x4-upscaler"
pipeline = StableDiffusionUpscalePipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipeline = pipeline.to("cuda")
# Out:
# Loading pipeline components...: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:01<00:00,  3.22it/s]

# %%
img_nums = [i for i in range(100)]
nsteps = 50

# %%
root = 'frames/lr'
root_save = "frames/sd-4x"

# %%
vid_num = '000'
for img in img_nums:
    im =  Image.open(os.path.join(root, vid_num, '{:08d}.png'.format(img))).convert("RGB")
    upscaled_im = pipeline(prompt="", image=im, num_inference_steps = nsteps).images[0]
    upscaled_im.save(os.path.join(root_save, vid_num, '{:08d}.png'.format(img)), format="PNG")
# Out:
# ...
#  60%|█████████████████████████████████████████████████████████████████████████████████████▊                                                         | 30/50 [00:02<00:01, 12.65it/s]

# %%
vid_num = '011'
for img in img_nums:
    im =  Image.open(os.path.join(root, vid_num, '{:08d}.png'.format(img))).convert("RGB")
    upscaled_im = pipeline(prompt="", image=im, num_inference_steps = nsteps).images[0]
    upscaled_im.save(os.path.join(root_save, vid_num, '{:08d}.png'.format(img)), format="PNG")
# Out:
# ...
#  16%|███████████████████████                                                                                                                         | 8/50 [00:00<00:03, 12.97it/s]

# %%
vid_num = '015'
for img in img_nums:
    im =  Image.open(os.path.join(root, vid_num, '{:08d}.png'.format(img))).convert("RGB")
    upscaled_im = pipeline(prompt="", image=im, num_inference_steps = nsteps).images[0]
    upscaled_im.save(os.path.join(root_save, vid_num, '{:08d}.png'.format(img)), format="PNG")

# %%
vid_num = '020'
for img in img_nums:
    im =  Image.open(os.path.join(root, vid_num, '{:08d}.png'.format(img))).convert("RGB")
    upscaled_im = pipeline(prompt="", image=im, num_inference_steps = nsteps).images[0]
    upscaled_im.save(os.path.join(root_save, vid_num, '{:08d}.png'.format(img)), format="PNG")
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.65it/s]
